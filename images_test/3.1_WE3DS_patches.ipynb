# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms
import segmentation_models_pytorch as smp
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
from thop import profile
import time

# %%
device = torch.device("cpu")
model_path = "../Fourth_training_phase/WE3DS/ENB0+UNet_models/WE3DS_seg_standard_DiceLoss.pth"

# %%
model = smp.Unet(
    encoder_name="efficientnet-b0",
    encoder_weights="imagenet",
    in_channels=3,
    classes=19
)

# %%
model.load_state_dict(torch.load(model_path, map_location=device))
model.to(device)
model.eval()
# Out:
# /tmp/ipykernel_2896506/1481618732.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=device))
# Unet(
#   (encoder): EfficientNetEncoder(
#     (_conv_stem): Conv2dStaticSamePadding(
#       3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False
#       (static_padding): ZeroPad2d((0, 1, 0, 1))
#     )
#     (_bn0): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     (_blocks): ModuleList(
#       (0): MBConvBlock(
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           32, 32, kernel_size=(3, 3), stride=[1, 1], groups=32, bias=False
#           (static_padding): ZeroPad2d((1, 1, 1, 1))
#         )
#         (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           32, 8, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           8, 32, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (1): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           96, 96, kernel_size=(3, 3), stride=[2, 2], groups=96, bias=False
#           (static_padding): ZeroPad2d((0, 1, 0, 1))
#         )
#         (_bn1): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           96, 4, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           4, 96, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (2): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           144, 144, kernel_size=(3, 3), stride=(1, 1), groups=144, bias=False
#           (static_padding): ZeroPad2d((1, 1, 1, 1))
#         )
#         (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           144, 6, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           6, 144, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (3): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           144, 144, kernel_size=(5, 5), stride=[2, 2], groups=144, bias=False
#           (static_padding): ZeroPad2d((1, 2, 1, 2))
#         )
#         (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           144, 6, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           6, 144, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (4): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           240, 240, kernel_size=(5, 5), stride=(1, 1), groups=240, bias=False
#           (static_padding): ZeroPad2d((2, 2, 2, 2))
#         )
#         (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           240, 10, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           10, 240, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (5): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           240, 240, kernel_size=(3, 3), stride=[2, 2], groups=240, bias=False
#           (static_padding): ZeroPad2d((0, 1, 0, 1))
#         )
#         (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           240, 10, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           10, 240, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (6-7): 2 x MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           480, 480, kernel_size=(3, 3), stride=(1, 1), groups=480, bias=False
#           (static_padding): ZeroPad2d((1, 1, 1, 1))
#         )
#         (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           480, 20, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           20, 480, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (8): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           480, 480, kernel_size=(5, 5), stride=[1, 1], groups=480, bias=False
#           (static_padding): ZeroPad2d((2, 2, 2, 2))
#         )
#         (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           480, 20, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           20, 480, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (9-10): 2 x MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           672, 672, kernel_size=(5, 5), stride=(1, 1), groups=672, bias=False
#           (static_padding): ZeroPad2d((2, 2, 2, 2))
#         )
#         (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           672, 28, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           28, 672, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (11): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           672, 672, kernel_size=(5, 5), stride=[2, 2], groups=672, bias=False
#           (static_padding): ZeroPad2d((1, 2, 1, 2))
#         )
#         (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           672, 28, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           28, 672, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (12-14): 3 x MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           1152, 1152, kernel_size=(5, 5), stride=(1, 1), groups=1152, bias=False
#           (static_padding): ZeroPad2d((2, 2, 2, 2))
#         )
#         (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           1152, 48, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           48, 1152, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (15): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           1152, 1152, kernel_size=(3, 3), stride=[1, 1], groups=1152, bias=False
#           (static_padding): ZeroPad2d((1, 1, 1, 1))
#         )
#         (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           1152, 48, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           48, 1152, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(320, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#     )
#     (_conv_head): Conv2dStaticSamePadding(
#       320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn1): BatchNorm2d(1280, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     (_avg_pooling): AdaptiveAvgPool2d(output_size=1)
#     (_dropout): Dropout(p=0.2, inplace=False)
#     (_swish): MemoryEfficientSwish()
#   )
#   (decoder): UnetDecoder(
#     (center): Identity()
#     (blocks): ModuleList(
#       (0): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(432, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (1): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(296, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (2): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(152, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (3): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (4): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#     )
#   )
#   (segmentation_head): SegmentationHead(
#     (0): Conv2d(16, 19, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Identity()
#     (2): Activation(
#       (activation): Identity()
#     )
#   )
# )

# %%
transform = transforms.Compose([
    transforms.Resize((256, 256)),   # resizing
    transforms.ToTensor(),           # [0,1]
])

# %%
# --- Patch Extraction con log ---
def extract_patches(image, patch_size):
    w, h = image.size
    patches = []
    positions = []
    step = patch_size 

    print(f"[INFO] Dimensione immagine: {w}x{h}")
    print(f"[INFO] Patch size: {patch_size}, Step: {step}")

    x_coords = list(range(0, w, step))
    y_coords = list(range(0, h, step))

    print(f"[INFO] Numero patch in orizzontale: {len(x_coords)}")
    print(f"[INFO] Numero patch in verticale: {len(y_coords)}")
    print(f"[INFO] Numero totale di patch: {len(x_coords) * len(y_coords)}")

    for top in y_coords:
        for left in x_coords:
            right = min(left + patch_size, w)
            bottom = min(top + patch_size, h)
            patches.append(image.crop((left, top, right, bottom)))
            positions.append((left, top, right, bottom))
            print(f"   Patch: left={left}, top={top}, right={right}, bottom={bottom}")

    return patches, positions, (w, h)

# %%
# --- Patch Reconstruction ---
def reconstruct_mask(patch_masks, positions, full_size):
    W, H = full_size
    full_mask = np.zeros((H, W), dtype=np.int64)
    count = np.zeros((H, W), dtype=np.int32)

    for mask, (left, top, right, bottom) in zip(patch_masks, positions):
        h, w = mask.shape
        full_mask[top:bottom, left:right] += mask
        count[top:bottom, left:right] += 1

    full_mask = np.divide(full_mask, count)
    return full_mask.astype(np.int64)

# %%
new_class_names  = ["soil", "common buckwheat", "weeds", "others"]
new_class_colors = np.array([
    [0, 0, 0],       # soil = nero
    [128, 0, 128],   # common buckwheat = viola
    [0, 255, 0],     # weeds = verde
    [192, 128, 0]    # others = arancione
])

# %%
orig_names = [
 "void","soil","broad bean","corn spurry","red-root amaranth","common buckwheat",
 "pea","red fingergrass","common wild oat","cornflower","corn cockle","corn",
 "milk thistle","rye brome","soybean","sunflower","narrow-leaved plantain",
 "small-flower geranium","sugar beet"
]

# Dizionario di rimappamento
remap = {}
for i, name in enumerate(orig_names):
    if name == "soil":
        remap[i] = 0                    # soil
    elif name == "common buckwheat":
        remap[i] = 1                    # common buckwheat
    elif name in [
        "corn spurry","red-root amaranth", "red fingergrass",
        "common wild oat","cornflower","corn cockle", "milk thistle",
        "rye brome", "narrow-leaved plantain", "small-flower geranium"
    ]:
        remap[i] = 2                    # weeds
    else:
        remap[i] = 3                    # others

# %%
def remap_mask(mask, remap_dict):
    out = np.zeros_like(mask, dtype=np.int64)
    for old_id, new_id in remap_dict.items():
        out[mask == old_id] = new_id
    return out

# %%
def decode_segmap(mask, class_colors):
    h, w = mask.shape
    color_mask = np.zeros((h, w, 3), dtype=np.uint8)
    for class_idx, color in enumerate(class_colors):
        color_mask[mask == class_idx] = color
    return color_mask

# %%
# --- Prediction con Patch ---
def predict_with_patches(image_path, patch_size):
    image = Image.open(image_path).convert("RGB")
    patches, positions, full_size = extract_patches(image, patch_size)

    patch_masks = []
    with torch.no_grad():
        for patch in patches:
            input_tensor = transform(patch).unsqueeze(0).to(device)
            output = model(input_tensor)
            mask = torch.argmax(output, dim=1).squeeze().cpu().numpy()
            mask = F.interpolate(torch.from_numpy(mask).unsqueeze(0).unsqueeze(0).float(),
                                 size=patch.size[::-1], mode='nearest').squeeze().numpy()
            patch_masks.append(mask.astype(np.int64))

    full_mask = reconstruct_mask(patch_masks, positions, full_size)
    full_mask = remap_mask(full_mask, remap)
    color_mask = decode_segmap(full_mask, new_class_colors)

    annotated_path = os.path.join(os.path.dirname(image_path), "annotated_image.png")
    annotated_image = Image.open(annotated_path).convert("RGB")

    #plt.subplot(1, 3, 1)
    #plt.imshow(image, interpolation="none")
    #plt.title("Original image")
    #plt.axis("off")

    #plt.subplot(1, 3, 2)
    #plt.imshow(annotated_image, interpolation="none")
    #plt.title("Segmentation mask")
    #plt.axis("off")

    plt.subplot(1, 3, 3)
    plt.imshow(color_mask, interpolation="none")
    #plt.title("Predicted mask")
    plt.axis("off")

    plt.tight_layout()
    plt.savefig("35patches_prediction.png", dpi=300, bbox_inches="tight")
    plt.show()

# --- Esegui ---
image_path = "../images/output_2_B/clean_image.png"
predict_with_patches(image_path, patch_size=448)
# 448 = 40 patches 
# 576 = 24 patches
# 960 = 12 patches
# 1140 = 6 patch
# 1636 = 4 patch
# 2236 = 2 patch
# Out:
# [INFO] Dimensione immagine: 3146x2235
# [INFO] Patch size: 448, Step: 448
# [INFO] Numero patch in orizzontale: 8
# [INFO] Numero patch in verticale: 5
# [INFO] Numero totale di patch: 40
#    Patch: left=0, top=0, right=448, bottom=448
#    Patch: left=448, top=0, right=896, bottom=448
#    Patch: left=896, top=0, right=1344, bottom=448
#    Patch: left=1344, top=0, right=1792, bottom=448
#    Patch: left=1792, top=0, right=2240, bottom=448
#    Patch: left=2240, top=0, right=2688, bottom=448
#    Patch: left=2688, top=0, right=3136, bottom=448
#    Patch: left=3136, top=0, right=3146, bottom=448
#    Patch: left=0, top=448, right=448, bottom=896
#    Patch: left=448, top=448, right=896, bottom=896
#    Patch: left=896, top=448, right=1344, bottom=896
#    Patch: left=1344, top=448, right=1792, bottom=896
#    Patch: left=1792, top=448, right=2240, bottom=896
#    Patch: left=2240, top=448, right=2688, bottom=896
#    Patch: left=2688, top=448, right=3136, bottom=896
#    Patch: left=3136, top=448, right=3146, bottom=896
#    Patch: left=0, top=896, right=448, bottom=1344
#    Patch: left=448, top=896, right=896, bottom=1344
#    Patch: left=896, top=896, right=1344, bottom=1344
#    Patch: left=1344, top=896, right=1792, bottom=1344
#    Patch: left=1792, top=896, right=2240, bottom=1344
#    Patch: left=2240, top=896, right=2688, bottom=1344
#    Patch: left=2688, top=896, right=3136, bottom=1344
#    Patch: left=3136, top=896, right=3146, bottom=1344
#    Patch: left=0, top=1344, right=448, bottom=1792
#    Patch: left=448, top=1344, right=896, bottom=1792
#    Patch: left=896, top=1344, right=1344, bottom=1792
#    Patch: left=1344, top=1344, right=1792, bottom=1792
#    Patch: left=1792, top=1344, right=2240, bottom=1792
#    Patch: left=2240, top=1344, right=2688, bottom=1792
#    Patch: left=2688, top=1344, right=3136, bottom=1792
#    Patch: left=3136, top=1344, right=3146, bottom=1792
#    Patch: left=0, top=1792, right=448, bottom=2235
#    Patch: left=448, top=1792, right=896, bottom=2235
#    Patch: left=896, top=1792, right=1344, bottom=2235
#    Patch: left=1344, top=1792, right=1792, bottom=2235
#    Patch: left=1792, top=1792, right=2240, bottom=2235
#    Patch: left=2240, top=1792, right=2688, bottom=2235
#    Patch: left=2688, top=1792, right=3136, bottom=2235
#    Patch: left=3136, top=1792, right=3146, bottom=2235

# %%
def predict_with_patches_metrics(image_path, patch_size):
    image = Image.open(image_path).convert("RGB")
    patches, positions, full_size = extract_patches(image, patch_size)

    patch_masks = []
    with torch.no_grad():
        for patch in patches:
            input_tensor = transform(patch).unsqueeze(0).to(device)
            output = model(input_tensor)
            mask = torch.argmax(output, dim=1).squeeze().cpu().numpy()

            # Upsampling per riportare la patch alle dimensioni originali
            mask = F.interpolate(
                torch.from_numpy(mask).unsqueeze(0).unsqueeze(0).float(),
                size=patch.size[::-1],  # (H, W)
                mode='nearest'
            ).squeeze().numpy()

            patch_masks.append(mask.astype(np.int64))

    # Ricostruisci la maschera intera
    full_mask = reconstruct_mask(patch_masks, positions, full_size)
    full_mask = remap_mask(full_mask, remap)  # rimappa alle 4 classi

    return full_mask

# %%
def load_ground_truth_masks(folder):
    """Costruisce la ground truth per soil, buckwheat e weeds a partire dalle maschere se presenti.
       Se una maschera non esiste, viene considerata tutta vuota.
    """
    # Percorsi
    buckwheat_path = os.path.join(folder, "mask[Grano saraceno].png")
    weeds_path = os.path.join(folder, "mask[Infestante].png")

    # Carica la maschera delle infestanti (obbligatoria)
    weeds_mask = np.array(Image.open(weeds_path).convert("L"))

    # Se la maschera del grano non esiste → maschera vuota
    if os.path.exists(buckwheat_path):
        buckwheat_mask = np.array(Image.open(buckwheat_path).convert("L"))
    else:
        buckwheat_mask = np.zeros_like(weeds_mask, dtype=np.uint8)

    # Binarizzazione
    buckwheat_bin = (buckwheat_mask > 0).astype(np.int64)
    weeds_bin = (weeds_mask > 0).astype(np.int64)

    # Soil = tutto ciò che non è buckwheat né weeds
    soil_bin = (1 - np.clip(buckwheat_bin + weeds_bin, 0, 1)).astype(np.int64)

    # Maschera finale
    gt_mask = np.zeros_like(soil_bin, dtype=np.int64)
    gt_mask[soil_bin == 1] = 0  # soil
    gt_mask[buckwheat_bin == 1] = 1  # buckwheat
    gt_mask[weeds_bin == 1] = 2  # weeds
    return gt_mask

# %%
def compute_metrics(y_true, y_pred, num_classes=3):
    """Calcola precision, recall, IoU e F1 per ciascuna classe, gestendo il caso di classe assente."""
    metrics = {}
    for c in range(num_classes):
        tp = np.sum((y_pred == c) & (y_true == c))
        fp = np.sum((y_pred == c) & (y_true != c))
        fn = np.sum((y_pred != c) & (y_true == c))

        # Caso speciale: classe assente nella GT
        if np.sum(y_true == c) == 0:
            if fp == 0:
                # Modello ha predetto correttamente "nessuna presenza" -> punteggio perfetto
                precision = recall = iou = f1 = 1.0
            else:
                # Modello ha predetto falsi positivi -> penalizzazione totale
                precision = recall = iou = f1 = 0.0
        else:
            precision = tp / (tp + fp + 1e-8)
            recall = tp / (tp + fn + 1e-8)
            iou = tp / (tp + fp + fn + 1e-8)
            f1 = 2 * precision * recall / (precision + recall + 1e-8)

        metrics[c] = {
            "precision": precision,
            "recall": recall,
            "iou": iou,
            "f1": f1
        }
    return metrics

# %%
all_times = []

# Classi
class_names = ["Soil", "Buckwheat", "Weeds"]

# 🔧 Calcolo dei GFLOPs una sola volta
# Assumendo che il tuo modello sia definito come "model"
# e che accetti input con dimensioni (1, 3, H, W)
model_cpu = model.to("cpu")
dummy_input = torch.randn(1, 3, 512, 512)  # modifica le dimensioni se necessario
macs, params = profile(model, inputs=(dummy_input,), verbose=False)
gflops = macs / 1e9  # conversione MACs → GFLOPs (1 GFLOP = 10^9 MACs)

print(f"\n⚙️  Stima GFLOPs modello: {gflops:.2f} GFLOPs")

# Itera su tutte le cartelle da output_1_A a output_20_B
for x in range(1, 21):
    for suffix in ["A", "B"]:
        folder = f"../images/output_{x}_{suffix}/"
        image_path = os.path.join(folder, "clean_image.png")
        
        if not os.path.exists(image_path):
            print(f"[SKIP] Immagine mancante in {folder}")
            continue

        # 1️⃣ Tempo di inferenza
        start_time = time.time()
        pred_mask = predict_with_patches_metrics(image_path, patch_size=1140)
        end_time = time.time()

        inference_time = end_time - start_time
        all_times.append(inference_time)

        print(f"📂 Cartella: {folder}")
        print(f"  ⏱️ Tempo inferenza: {inference_time:.4f} s")

# --- 📊 Risultati finali ---
if all_times:
    avg_time = np.mean(all_times)
    print("\n====================")
    print("📊 RISULTATI GLOBALI")
    print("====================")
    print(f"⏱️ Tempo medio di inferenza per immagine: {avg_time:.4f} s")
    print(f"🧮 GFLOPs richiesti: {gflops:.2f} GFLOPs")
else:
    print("\n⚠️ Nessuna inferenza eseguita: controlla che le cartelle e le immagini esistano.")
# Out:
# ⚙️  Stima GFLOPs modello: 10.81 GFLOPs
# [INFO] Dimensione immagine: 3102x2223
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3102, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2223
#    Patch: left=1140, top=1140, right=2280, bottom=2223
#    Patch: left=2280, top=1140, right=3102, bottom=2223
# 📂 Cartella: ../images/output_1_A/
#   ⏱️ Tempo inferenza: 0.5470 s
# [INFO] Dimensione immagine: 2980x2137
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=2980, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2137
#    Patch: left=1140, top=1140, right=2280, bottom=2137
#    Patch: left=2280, top=1140, right=2980, bottom=2137
# 📂 Cartella: ../images/output_1_B/
#   ⏱️ Tempo inferenza: 0.5197 s
# [INFO] Dimensione immagine: 3101x2223
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3101, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2223
#    Patch: left=1140, top=1140, right=2280, bottom=2223
#    Patch: left=2280, top=1140, right=3101, bottom=2223
# 📂 Cartella: ../images/output_2_A/
#   ⏱️ Tempo inferenza: 0.5510 s
# [INFO] Dimensione immagine: 3146x2235
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3146, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2235
#    Patch: left=1140, top=1140, right=2280, bottom=2235
#    Patch: left=2280, top=1140, right=3146, bottom=2235
# 📂 Cartella: ../images/output_2_B/
#   ⏱️ Tempo inferenza: 0.5566 s
# [INFO] Dimensione immagine: 3158x2212
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3158, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2212
#    Patch: left=1140, top=1140, right=2280, bottom=2212
#    Patch: left=2280, top=1140, right=3158, bottom=2212
# 📂 Cartella: ../images/output_3_A/
#   ⏱️ Tempo inferenza: 0.5547 s
# [INFO] Dimensione immagine: 3207x2201
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3207, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2201
#    Patch: left=1140, top=1140, right=2280, bottom=2201
#    Patch: left=2280, top=1140, right=3207, bottom=2201
# 📂 Cartella: ../images/output_3_B/
#   ⏱️ Tempo inferenza: 0.5617 s
# [INFO] Dimensione immagine: 3154x2208
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3154, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2208
#    Patch: left=1140, top=1140, right=2280, bottom=2208
#    Patch: left=2280, top=1140, right=3154, bottom=2208
# 📂 Cartella: ../images/output_4_A/
#   ⏱️ Tempo inferenza: 0.5531 s
# [INFO] Dimensione immagine: 3215x2235
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3215, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2235
#    Patch: left=1140, top=1140, right=2280, bottom=2235
#    Patch: left=2280, top=1140, right=3215, bottom=2235
# 📂 Cartella: ../images/output_4_B/
#   ⏱️ Tempo inferenza: 0.5588 s
# [INFO] Dimensione immagine: 3006x2175
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3006, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2175
#    Patch: left=1140, top=1140, right=2280, bottom=2175
#    Patch: left=2280, top=1140, right=3006, bottom=2175
# 📂 Cartella: ../images/output_5_A/
#   ⏱️ Tempo inferenza: 0.5309 s
# [INFO] Dimensione immagine: 3188x2219
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3188, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2219
#    Patch: left=1140, top=1140, right=2280, bottom=2219
#    Patch: left=2280, top=1140, right=3188, bottom=2219
# 📂 Cartella: ../images/output_5_B/
#   ⏱️ Tempo inferenza: 0.5523 s
# [INFO] Dimensione immagine: 3120x2201
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3120, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2201
#    Patch: left=1140, top=1140, right=2280, bottom=2201
#    Patch: left=2280, top=1140, right=3120, bottom=2201
# 📂 Cartella: ../images/output_6_A/
#   ⏱️ Tempo inferenza: 0.5469 s
# [INFO] Dimensione immagine: 3132x2223
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3132, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2223
#    Patch: left=1140, top=1140, right=2280, bottom=2223
#    Patch: left=2280, top=1140, right=3132, bottom=2223
# 📂 Cartella: ../images/output_6_B/
#   ⏱️ Tempo inferenza: 0.5542 s
# [INFO] Dimensione immagine: 3078x2148
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3078, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2148
#    Patch: left=1140, top=1140, right=2280, bottom=2148
#    Patch: left=2280, top=1140, right=3078, bottom=2148
# 📂 Cartella: ../images/output_7_A/
#   ⏱️ Tempo inferenza: 0.5400 s
# [INFO] Dimensione immagine: 3070x2204
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3070, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2204
#    Patch: left=1140, top=1140, right=2280, bottom=2204
#    Patch: left=2280, top=1140, right=3070, bottom=2204
# 📂 Cartella: ../images/output_7_B/
#   ⏱️ Tempo inferenza: 0.5467 s
# [INFO] Dimensione immagine: 3116x2193
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3116, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2193
#    Patch: left=1140, top=1140, right=2280, bottom=2193
#    Patch: left=2280, top=1140, right=3116, bottom=2193
# 📂 Cartella: ../images/output_8_A/
#   ⏱️ Tempo inferenza: 0.5547 s
# [INFO] Dimensione immagine: 3082x2186
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3082, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2186
#    Patch: left=1140, top=1140, right=2280, bottom=2186
#    Patch: left=2280, top=1140, right=3082, bottom=2186
# 📂 Cartella: ../images/output_8_B/
#   ⏱️ Tempo inferenza: 0.5391 s
# [INFO] Dimensione immagine: 3200x2227
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3200, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2227
#    Patch: left=1140, top=1140, right=2280, bottom=2227
#    Patch: left=2280, top=1140, right=3200, bottom=2227
# 📂 Cartella: ../images/output_9_A/
#   ⏱️ Tempo inferenza: 0.5619 s
# [INFO] Dimensione immagine: 3117x2216
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3117, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2216
#    Patch: left=1140, top=1140, right=2280, bottom=2216
#    Patch: left=2280, top=1140, right=3117, bottom=2216
# 📂 Cartella: ../images/output_9_B/
#   ⏱️ Tempo inferenza: 0.5496 s
# [INFO] Dimensione immagine: 3017x2156
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3017, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2156
#    Patch: left=1140, top=1140, right=2280, bottom=2156
#    Patch: left=2280, top=1140, right=3017, bottom=2156
# 📂 Cartella: ../images/output_10_A/
#   ⏱️ Tempo inferenza: 0.5406 s
# [INFO] Dimensione immagine: 3078x2163
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3078, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2163
#    Patch: left=1140, top=1140, right=2280, bottom=2163
#    Patch: left=2280, top=1140, right=3078, bottom=2163
# 📂 Cartella: ../images/output_10_B/
#   ⏱️ Tempo inferenza: 0.5403 s
# [INFO] Dimensione immagine: 3078x2160
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3078, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2160
#    Patch: left=1140, top=1140, right=2280, bottom=2160
#    Patch: left=2280, top=1140, right=3078, bottom=2160
# 📂 Cartella: ../images/output_11_A/
#   ⏱️ Tempo inferenza: 0.5395 s
# [INFO] Dimensione immagine: 3044x2137
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3044, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2137
#    Patch: left=1140, top=1140, right=2280, bottom=2137
#    Patch: left=2280, top=1140, right=3044, bottom=2137
# 📂 Cartella: ../images/output_11_B/
#   ⏱️ Tempo inferenza: 0.5326 s
# [INFO] Dimensione immagine: 3063x2178
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3063, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2178
#    Patch: left=1140, top=1140, right=2280, bottom=2178
#    Patch: left=2280, top=1140, right=3063, bottom=2178
# 📂 Cartella: ../images/output_12_A/
#   ⏱️ Tempo inferenza: 0.5435 s
# [INFO] Dimensione immagine: 3066x2193
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3066, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2193
#    Patch: left=1140, top=1140, right=2280, bottom=2193
#    Patch: left=2280, top=1140, right=3066, bottom=2193
# 📂 Cartella: ../images/output_12_B/
#   ⏱️ Tempo inferenza: 0.5424 s
# [INFO] Dimensione immagine: 3200x2227
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3200, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2227
#    Patch: left=1140, top=1140, right=2280, bottom=2227
#    Patch: left=2280, top=1140, right=3200, bottom=2227
# 📂 Cartella: ../images/output_13_A/
#   ⏱️ Tempo inferenza: 0.5597 s
# [INFO] Dimensione immagine: 3124x2216
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3124, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2216
#    Patch: left=1140, top=1140, right=2280, bottom=2216
#    Patch: left=2280, top=1140, right=3124, bottom=2216
# 📂 Cartella: ../images/output_13_B/
#   ⏱️ Tempo inferenza: 0.5637 s
# [INFO] Dimensione immagine: 3040x2156
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3040, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2156
#    Patch: left=1140, top=1140, right=2280, bottom=2156
#    Patch: left=2280, top=1140, right=3040, bottom=2156
# 📂 Cartella: ../images/output_14_A/
#   ⏱️ Tempo inferenza: 0.5329 s
# [INFO] Dimensione immagine: 3070x2171
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3070, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2171
#    Patch: left=1140, top=1140, right=2280, bottom=2171
#    Patch: left=2280, top=1140, right=3070, bottom=2171
# 📂 Cartella: ../images/output_14_B/
#   ⏱️ Tempo inferenza: 0.5426 s
# [INFO] Dimensione immagine: 3146x2186
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3146, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2186
#    Patch: left=1140, top=1140, right=2280, bottom=2186
#    Patch: left=2280, top=1140, right=3146, bottom=2186
# 📂 Cartella: ../images/output_15_A/
#   ⏱️ Tempo inferenza: 0.5438 s
# [INFO] Dimensione immagine: 3196x2212
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3196, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2212
#    Patch: left=1140, top=1140, right=2280, bottom=2212
#    Patch: left=2280, top=1140, right=3196, bottom=2212
# 📂 Cartella: ../images/output_15_B/
#   ⏱️ Tempo inferenza: 0.5664 s
# [INFO] Dimensione immagine: 3143x2226
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3143, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2226
#    Patch: left=1140, top=1140, right=2280, bottom=2226
#    Patch: left=2280, top=1140, right=3143, bottom=2226
# 📂 Cartella: ../images/output_16_A/
#   ⏱️ Tempo inferenza: 0.5550 s
# [INFO] Dimensione immagine: 3128x2223
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3128, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2223
#    Patch: left=1140, top=1140, right=2280, bottom=2223
#    Patch: left=2280, top=1140, right=3128, bottom=2223
# 📂 Cartella: ../images/output_16_B/
#   ⏱️ Tempo inferenza: 0.5790 s
# [INFO] Dimensione immagine: 3102x2182
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3102, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2182
#    Patch: left=1140, top=1140, right=2280, bottom=2182
#    Patch: left=2280, top=1140, right=3102, bottom=2182
# 📂 Cartella: ../images/output_17_A/
#   ⏱️ Tempo inferenza: 0.5446 s
# [INFO] Dimensione immagine: 3063x2193
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3063, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2193
#    Patch: left=1140, top=1140, right=2280, bottom=2193
#    Patch: left=2280, top=1140, right=3063, bottom=2193
# 📂 Cartella: ../images/output_17_B/
#   ⏱️ Tempo inferenza: 0.5308 s
# [INFO] Dimensione immagine: 3124x2231
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3124, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2231
#    Patch: left=1140, top=1140, right=2280, bottom=2231
#    Patch: left=2280, top=1140, right=3124, bottom=2231
# 📂 Cartella: ../images/output_18_A/
#   ⏱️ Tempo inferenza: 0.5545 s
# [INFO] Dimensione immagine: 3752x2676
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 4
# [INFO] Numero patch in verticale: 3
# [INFO] Numero totale di patch: 12
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3420, bottom=1140
#    Patch: left=3420, top=0, right=3752, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2280
#    Patch: left=1140, top=1140, right=2280, bottom=2280
#    Patch: left=2280, top=1140, right=3420, bottom=2280
#    Patch: left=3420, top=1140, right=3752, bottom=2280
#    Patch: left=0, top=2280, right=1140, bottom=2676
#    Patch: left=1140, top=2280, right=2280, bottom=2676
#    Patch: left=2280, top=2280, right=3420, bottom=2676
#    Patch: left=3420, top=2280, right=3752, bottom=2676
# 📂 Cartella: ../images/output_18_B/
#   ⏱️ Tempo inferenza: 0.9074 s
# [INFO] Dimensione immagine: 3233x2208
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3233, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2208
#    Patch: left=1140, top=1140, right=2280, bottom=2208
#    Patch: left=2280, top=1140, right=3233, bottom=2208
# 📂 Cartella: ../images/output_19_A/
#   ⏱️ Tempo inferenza: 0.5611 s
# [INFO] Dimensione immagine: 3759x2704
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 4
# [INFO] Numero patch in verticale: 3
# [INFO] Numero totale di patch: 12
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3420, bottom=1140
#    Patch: left=3420, top=0, right=3759, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2280
#    Patch: left=1140, top=1140, right=2280, bottom=2280
#    Patch: left=2280, top=1140, right=3420, bottom=2280
#    Patch: left=3420, top=1140, right=3759, bottom=2280
#    Patch: left=0, top=2280, right=1140, bottom=2704
#    Patch: left=1140, top=2280, right=2280, bottom=2704
#    Patch: left=2280, top=2280, right=3420, bottom=2704
#    Patch: left=3420, top=2280, right=3759, bottom=2704
# 📂 Cartella: ../images/output_19_B/
#   ⏱️ Tempo inferenza: 0.9451 s
# [INFO] Dimensione immagine: 3165x2227
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3165, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2227
#    Patch: left=1140, top=1140, right=2280, bottom=2227
#    Patch: left=2280, top=1140, right=3165, bottom=2227
# 📂 Cartella: ../images/output_20_A/
#   ⏱️ Tempo inferenza: 0.5593 s
# [INFO] Dimensione immagine: 3097x2174
# [INFO] Patch size: 1140, Step: 1140
# [INFO] Numero patch in orizzontale: 3
# [INFO] Numero patch in verticale: 2
# [INFO] Numero totale di patch: 6
#    Patch: left=0, top=0, right=1140, bottom=1140
#    Patch: left=1140, top=0, right=2280, bottom=1140
#    Patch: left=2280, top=0, right=3097, bottom=1140
#    Patch: left=0, top=1140, right=1140, bottom=2174
#    Patch: left=1140, top=1140, right=2280, bottom=2174
#    Patch: left=2280, top=1140, right=3097, bottom=2174
# 📂 Cartella: ../images/output_20_B/
#   ⏱️ Tempo inferenza: 0.5346 s
#
# ====================
# 📊 RISULTATI GLOBALI
# ====================
# ⏱️ Tempo medio di inferenza per immagine: 0.5675 s
# 🧮 GFLOPs richiesti: 10.81 GFLOPs
