# %%
import os
import numpy as np
import cv2
import random
from torch.utils.data import Dataset, DataLoader
import segmentation_models_pytorch as smp
import torch
import torch.nn as nn
from tqdm import tqdm
import albumentations as A
import matplotlib.pyplot as plt
from torchmetrics import F1Score, Precision, Recall
import wandb
# Out:
# /media/HDD/fdittaro/env/lib/python3.8/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 2.0.8 (you have 1.4.18). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
wandb.login()
# Out:
# wandb: Currently logged in as: federico-dittaro (federico-dittaro-university-of-udine) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
wandb.init(
    project="Second_phase_WE3DS_dataset-segmentation",
    group="MobileNetV2_UNet", 
    tags=["batch_64"],
    name=f"run_WE3DS_seg_MNV2+UNet_bs64",
    config={
        "epochs": 50,
        "batch_size": 64
    }
)
# Out:
# wandb: Currently logged in as: federico-dittaro (federico-dittaro-university-of-udine) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/media/HDD/fdittaro/Second_traing_phase/MNV2+UNet/WE3DS/wandb/run-20250714_140435-q9bhkbf2</code>
# Syncing run <strong><a href='https://wandb.ai/federico-dittaro-university-of-udine/Second_phase_WE3DS_dataset-segmentation/runs/q9bhkbf2' target="_blank">run_WE3DS_seg_MNV2+UNet_bs64</a></strong> to <a href='https://wandb.ai/federico-dittaro-university-of-udine/Second_phase_WE3DS_dataset-segmentation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/federico-dittaro-university-of-udine/Second_phase_WE3DS_dataset-segmentation' target="_blank">https://wandb.ai/federico-dittaro-university-of-udine/Second_phase_WE3DS_dataset-segmentation</a>
#  View run at <a href='https://wandb.ai/federico-dittaro-university-of-udine/Second_phase_WE3DS_dataset-segmentation/runs/q9bhkbf2' target="_blank">https://wandb.ai/federico-dittaro-university-of-udine/Second_phase_WE3DS_dataset-segmentation/runs/q9bhkbf2</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/federico-dittaro-university-of-udine/Second_phase_WE3DS_dataset-segmentation/runs/q9bhkbf2?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
# Unisce tutti gli ID in un unico elenco esuddivide il dataset in 70/15/15 (training , validation, test)
random.seed(42)
with open("../../../WE3DS-dataset/train.txt") as f:
    train_ids = [line.strip() for line in f]
with open("../../../WE3DS-dataset/test.txt") as f:
    test_ids = [line.strip() for line in f]

all_ids = train_ids + test_ids
total = len(all_ids)

random.shuffle(all_ids)
train_size = int(total * 0.70)
val_size = int(total * 0.15)
test_size = total - train_size - val_size

train_ids = all_ids[:train_size]
val_ids = all_ids[train_size:train_size + val_size]
test_ids = all_ids[train_size + val_size:]

print(f"Training set: {len(train_ids)} immagini")
print(f"Validation set: {len(val_ids)} immagini")
print(f"Test set: {len(test_ids)} immagini")
# Out:
# Training set: 1797 immagini
# Validation set: 385 immagini
# Test set: 386 immagini

# %%
class WE3DSDataset(Dataset):
    """
    image_ids: lista degli ID immagine
    images_dir: cartella dove si trovano le immagini
    masks_dir: cartella dove si trovano le maschere corrispondenti
    transform: trasformazioni da applicare
    """
    def __init__(self, image_ids, images_dir, masks_dir, transform=None):
        self.image_ids = image_ids
        self.images_dir = images_dir
        self.masks_dir = masks_dir
        self.transform = transform

    """ Restituisce la lunghezza del dataset (necessario per PyTorch DataLoader)."""
    def __len__(self):
        return len(self.image_ids)

    """ 
    Dato un indice recupera la coppia (immagine, maschera), applica trasformazioni coerenti ad entrambi
    e le converte in tensori Pytorch.
    """
    def __getitem__(self, idx):
        img_id = self.image_ids[idx]
        img_path = os.path.join(self.images_dir, f"img_{img_id}.png")
        mask_path = os.path.join(self.masks_dir, f"img_{img_id}.png")

        image = cv2.cvtColor(cv2.imread(img_path), cv2.COLOR_BGR2RGB)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

        if self.transform:
            augmented = self.transform(image=image, mask=mask)
            image = torch.tensor(np.array(augmented['image']) / 255.0, dtype=torch.float32).permute(2, 0, 1)
            mask = torch.tensor(np.array(augmented['mask']), dtype=torch.long)

        return image, mask

""" Ridimensiona immagini e maschere a (256,256) """
train_transform = A.Compose([A.Resize(256, 256)])
val_transform = A.Compose([A.Resize(256, 256)])
test_transform = A.Compose([A.Resize(256, 256)])

images_dir = "../../../WE3DS-dataset/images"
masks_dir = "../../../WE3DS-dataset/annotations/segmentation/SegmentationLabel"

train_loader = DataLoader(WE3DSDataset(train_ids, images_dir, masks_dir, transform=train_transform), batch_size=64, shuffle=True)
val_loader = DataLoader(WE3DSDataset(val_ids, images_dir, masks_dir, transform=val_transform), batch_size=64, shuffle=False)
test_loader = DataLoader(WE3DSDataset(test_ids, images_dir, masks_dir, transform=test_transform), batch_size=64, shuffle=False)

# %%
"""Costruzione del modello UNet con MobileNetV2 come backbone. Il modello carica pesi pre-addestrati su ImageNet
per l'encoder. Le immagini in input hanno tre canali (RGB) e 19 classi di output (una per ciascuna classe di
segmentazione)"""
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

model = smp.Unet(
    encoder_name="mobilenet_v2",
    encoder_weights="imagenet",
    in_channels=3,
    classes=19
)

num_params = count_parameters(model)
print(f" Numero di parametri allenabili: {num_params:,}")
# Out:
#  Numero di parametri allenabili: 6,631,555

# %%
"""Imposta il dispositivo di calcolo sulla GPU e sposta il modello sul dispositivo. 
Utilizza la Cross Entropy Loss come funzione di perdita e Adam come ottimizzatore con leraning rate 0.001"""
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %%
"""Calcolo dell'IoU:
- intersection: numero di pixel correttamente classificati per quella classe
- union: tutti i pixel predetti o etichettati come quella classe
Restituisce la media delle IoU tra tutte le classi, ignorando i nan (classe non presente nè nella predizione
nè nella label)"""
def compute_iou(preds, labels, num_classes):
    preds = torch.argmax(preds, dim=1).view(-1)
    labels = labels.view(-1)
    ious = []
    for cls in range(num_classes):
        pred_inds = preds == cls
        target_inds = labels == cls
        intersection = (pred_inds & target_inds).sum().item()
        union = (pred_inds | target_inds).sum().item()
        if union == 0:
            ious.append(float('nan'))
        else:
            ious.append(intersection / union)
    return torch.tensor(ious).nanmean().item()

# %%
"""Addestramento del modello per una singola epoca"""
def train_one_epoch(model, dataloader, loss_fn, optimizer):
    model.train()
    running_loss = 0
    for images, masks in tqdm(dataloader, desc="Training"):
        images, masks = images.to(device), masks.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = loss_fn(outputs, masks)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    return running_loss / len(dataloader)

"""Valuta il modello su un dataloader di validazione (senza l'aggiornamento dei pesi)"""
def validate(model, dataloader, loss_fn):
    f1_metric = F1Score(num_classes=19, average='macro', task='multiclass').to(device)
    precision_metric = Precision(num_classes=19, average='macro', task='multiclass').to(device)
    recall_metric = Recall(num_classes=19, average='macro', task='multiclass').to(device)
    model.eval()
    val_loss = 0
    iou_total = 0
    with torch.no_grad():
        for images, masks in tqdm(dataloader, desc="Validation"):
            images, masks = images.to(device), masks.to(device)
            outputs = model(images)
            preds = torch.argmax(outputs, dim=1)
            f1_metric.update(preds, masks)
            precision_metric.update(preds, masks)
            recall_metric.update(preds, masks)
            loss = loss_fn(outputs, masks)
            val_loss += loss.item()
            iou_total += compute_iou(outputs, masks, num_classes=19)
    val_f1 = f1_metric.compute().item()
    val_precision = precision_metric.compute().item()
    val_recall = recall_metric.compute().item()
    return val_loss / len(dataloader), iou_total / len(dataloader), val_f1, val_precision, val_recall

# %%
"""Addestra il modello per 50 epoche salvando il modello migliore. L'addestramento si interrompe se per 10 epoche
non avviene nessun miglioramento."""
num_epochs = 50
best_val_loss = float('inf')
patience = 10
counter = 0

for epoch in range(num_epochs):
    print(f"\nEpoch {epoch+1}/{num_epochs}")
    train_loss = train_one_epoch(model, train_loader, loss_fn, optimizer)
    val_loss, val_iou, val_f1, val_precision, val_recall = validate(model, val_loader, loss_fn)

    print(f"Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | IoU: {val_iou:.4f} | F1: {val_f1:.4f} | Precision: {val_precision:.4f} | Recall: {val_recall:.4f}")

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), "MNV2+UNet_models/MBV2UNet_WE3DS_segmentation_bs64.pth")
        print("✅ Model saved.")
        counter = 0
    else:
        counter += 1
        print(f"No improvement. EarlyStopping counter: {counter}/{patience}")
        if counter >= patience:
            print("⏹️ Early stopping triggered.")
            break

    wandb.log({
        "train_loss": train_loss,
        "val_loss": val_loss,
        "val_iou": val_iou,
        "val_f1": val_f1,
        "val_precision": val_precision,
        "val_recall": val_recall
    })

wandb.finish()
# Out:
# Epoch 1/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [02:14<00:00,  4.65s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:24<00:00,  3.56s/it]
# Train Loss: 1.7319 | Val Loss: 0.8403 | IoU: 0.0994 | F1: 0.0582 | Precision: 0.0575 | Recall: 0.0588
# ✅ Model saved.
#
# Epoch 2/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.2678 | Val Loss: 0.1747 | IoU: 0.1232 | F1: 0.0582 | Precision: 0.0575 | Recall: 0.0588
# ✅ Model saved.
#
# Epoch 3/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.70s/it]
# Train Loss: 0.1113 | Val Loss: 0.1050 | IoU: 0.1315 | F1: 0.0643 | Precision: 0.0625 | Recall: 0.0670
# ✅ Model saved.
#
# Epoch 4/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0923 | Val Loss: 0.0918 | IoU: 0.1124 | F1: 0.0757 | Precision: 0.0715 | Recall: 0.0830
# ✅ Model saved.
#
# Epoch 5/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.70s/it]
# Train Loss: 0.0830 | Val Loss: 0.0835 | IoU: 0.1077 | F1: 0.0717 | Precision: 0.1176 | Recall: 0.0945
# ✅ Model saved.
#
# Epoch 6/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.70s/it]
# Train Loss: 0.0780 | Val Loss: 0.0792 | IoU: 0.1071 | F1: 0.0694 | Precision: 0.0939 | Recall: 0.1051
# ✅ Model saved.
#
# Epoch 7/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0698 | Val Loss: 0.0737 | IoU: 0.1063 | F1: 0.0820 | Precision: 0.1187 | Recall: 0.1094
# ✅ Model saved.
#
# Epoch 8/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0656 | Val Loss: 0.0714 | IoU: 0.1044 | F1: 0.0884 | Precision: 0.1286 | Recall: 0.1087
# ✅ Model saved.
#
# Epoch 9/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0647 | Val Loss: 0.0701 | IoU: 0.1096 | F1: 0.0744 | Precision: 0.1385 | Recall: 0.1087
# ✅ Model saved.
#
# Epoch 10/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0615 | Val Loss: 0.0733 | IoU: 0.1181 | F1: 0.0814 | Precision: 0.1671 | Recall: 0.1146
# No improvement. EarlyStopping counter: 1/10
#
# Epoch 11/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.70s/it]
# Train Loss: 0.0596 | Val Loss: 0.0635 | IoU: 0.1038 | F1: 0.0857 | Precision: 0.1562 | Recall: 0.1115
# ✅ Model saved.
#
# Epoch 12/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.70s/it]
# Train Loss: 0.0570 | Val Loss: 0.0621 | IoU: 0.1168 | F1: 0.1069 | Precision: 0.1505 | Recall: 0.1332
# ✅ Model saved.
#
# Epoch 13/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0589 | Val Loss: 0.0635 | IoU: 0.1270 | F1: 0.1198 | Precision: 0.1654 | Recall: 0.1614
# No improvement. EarlyStopping counter: 1/10
#
# Epoch 14/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0601 | Val Loss: 0.0648 | IoU: 0.1182 | F1: 0.1092 | Precision: 0.1645 | Recall: 0.1585
# No improvement. EarlyStopping counter: 2/10
#
# Epoch 15/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0600 | Val Loss: 0.0615 | IoU: 0.1433 | F1: 0.1174 | Precision: 0.1737 | Recall: 0.1682
# ✅ Model saved.
#
# Epoch 16/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0609 | Val Loss: 0.0647 | IoU: 0.1225 | F1: 0.1174 | Precision: 0.1744 | Recall: 0.1707
# No improvement. EarlyStopping counter: 1/10
#
# Epoch 17/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.70s/it]
# Train Loss: 0.0541 | Val Loss: 0.0617 | IoU: 0.1364 | F1: 0.1200 | Precision: 0.1721 | Recall: 0.1749
# No improvement. EarlyStopping counter: 2/10
#
# Epoch 18/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0511 | Val Loss: 0.0604 | IoU: 0.1490 | F1: 0.1366 | Precision: 0.1844 | Recall: 0.1649
# ✅ Model saved.
#
# Epoch 19/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0494 | Val Loss: 0.0535 | IoU: 0.1493 | F1: 0.1419 | Precision: 0.1938 | Recall: 0.1964
# ✅ Model saved.
#
# Epoch 20/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.70s/it]
# Train Loss: 0.0462 | Val Loss: 0.0519 | IoU: 0.1693 | F1: 0.1796 | Precision: 0.2224 | Recall: 0.2261
# ✅ Model saved.
#
# Epoch 21/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0456 | Val Loss: 0.0484 | IoU: 0.2221 | F1: 0.2411 | Precision: 0.2721 | Recall: 0.2703
# ✅ Model saved.
#
# Epoch 22/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0433 | Val Loss: 0.0477 | IoU: 0.2354 | F1: 0.2716 | Precision: 0.3020 | Recall: 0.2863
# ✅ Model saved.
#
# Epoch 23/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0416 | Val Loss: 0.0587 | IoU: 0.1816 | F1: 0.1922 | Precision: 0.2090 | Recall: 0.2365
# No improvement. EarlyStopping counter: 1/10
#
# Epoch 24/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.19s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0395 | Val Loss: 0.0459 | IoU: 0.2285 | F1: 0.2923 | Precision: 0.3170 | Recall: 0.3086
# ✅ Model saved.
#
# Epoch 25/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.19s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0408 | Val Loss: 0.0512 | IoU: 0.2310 | F1: 0.2751 | Precision: 0.3021 | Recall: 0.2835
# No improvement. EarlyStopping counter: 1/10
#
# Epoch 26/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0437 | Val Loss: 0.0561 | IoU: 0.1938 | F1: 0.2573 | Precision: 0.2698 | Recall: 0.2925
# No improvement. EarlyStopping counter: 2/10
#
# Epoch 27/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0460 | Val Loss: 0.0515 | IoU: 0.1944 | F1: 0.2149 | Precision: 0.2474 | Recall: 0.2467
# No improvement. EarlyStopping counter: 3/10
#
# Epoch 28/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0424 | Val Loss: 0.0519 | IoU: 0.1939 | F1: 0.2640 | Precision: 0.2880 | Recall: 0.2711
# No improvement. EarlyStopping counter: 4/10
#
# Epoch 29/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.17s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0459 | Val Loss: 0.0448 | IoU: 0.2372 | F1: 0.2890 | Precision: 0.3231 | Recall: 0.2997
# ✅ Model saved.
#
# Epoch 30/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0398 | Val Loss: 0.0400 | IoU: 0.2633 | F1: 0.3261 | Precision: 0.3389 | Recall: 0.3511
# ✅ Model saved.
#
# Epoch 31/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0382 | Val Loss: 0.0431 | IoU: 0.2772 | F1: 0.3075 | Precision: 0.3423 | Recall: 0.3140
# No improvement. EarlyStopping counter: 1/10
#
# Epoch 32/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.70s/it]
# Train Loss: 0.0372 | Val Loss: 0.0494 | IoU: 0.2293 | F1: 0.2611 | Precision: 0.2855 | Recall: 0.2839
# No improvement. EarlyStopping counter: 2/10
#
# Epoch 33/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0383 | Val Loss: 0.0494 | IoU: 0.2514 | F1: 0.3026 | Precision: 0.3396 | Recall: 0.3335
# No improvement. EarlyStopping counter: 3/10
#
# Epoch 34/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0365 | Val Loss: 0.0429 | IoU: 0.2791 | F1: 0.3273 | Precision: 0.3575 | Recall: 0.3348
# No improvement. EarlyStopping counter: 4/10
#
# Epoch 35/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0332 | Val Loss: 0.0408 | IoU: 0.2643 | F1: 0.3357 | Precision: 0.3531 | Recall: 0.3547
# No improvement. EarlyStopping counter: 5/10
#
# Epoch 36/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0340 | Val Loss: 0.0362 | IoU: 0.2958 | F1: 0.3340 | Precision: 0.3707 | Recall: 0.3507
# ✅ Model saved.
#
# Epoch 37/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0329 | Val Loss: 0.0410 | IoU: 0.2470 | F1: 0.3204 | Precision: 0.3640 | Recall: 0.3376
# No improvement. EarlyStopping counter: 1/10
#
# Epoch 38/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.20s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0297 | Val Loss: 0.0324 | IoU: 0.3151 | F1: 0.3525 | Precision: 0.3750 | Recall: 0.3663
# ✅ Model saved.
#
# Epoch 39/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:41<00:00,  3.49s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0298 | Val Loss: 0.0383 | IoU: 0.2903 | F1: 0.3328 | Precision: 0.3661 | Recall: 0.3661
# No improvement. EarlyStopping counter: 1/10
#
# Epoch 40/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.70s/it]
# Train Loss: 0.0382 | Val Loss: 0.0529 | IoU: 0.2567 | F1: 0.3173 | Precision: 0.3534 | Recall: 0.3379
# No improvement. EarlyStopping counter: 2/10
#
# Epoch 41/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0434 | Val Loss: 0.0469 | IoU: 0.2396 | F1: 0.2866 | Precision: 0.3005 | Recall: 0.3230
# No improvement. EarlyStopping counter: 3/10
#
# Epoch 42/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.70s/it]
# Train Loss: 0.0383 | Val Loss: 0.0415 | IoU: 0.2955 | F1: 0.3338 | Precision: 0.3430 | Recall: 0.3671
# No improvement. EarlyStopping counter: 4/10
#
# Epoch 43/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:19<00:00,  2.71s/it]
# Train Loss: 0.0304 | Val Loss: 0.0442 | IoU: 0.2745 | F1: 0.3147 | Precision: 0.3560 | Recall: 0.3299
# No improvement. EarlyStopping counter: 5/10
#
# Epoch 44/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0332 | Val Loss: 0.0477 | IoU: 0.2742 | F1: 0.3362 | Precision: 0.3964 | Recall: 0.3496
# No improvement. EarlyStopping counter: 6/10
#
# Epoch 45/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0293 | Val Loss: 0.0400 | IoU: 0.3084 | F1: 0.3544 | Precision: 0.4358 | Recall: 0.3725
# No improvement. EarlyStopping counter: 7/10
#
# Epoch 46/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0282 | Val Loss: 0.0381 | IoU: 0.3139 | F1: 0.3608 | Precision: 0.3953 | Recall: 0.3838
# No improvement. EarlyStopping counter: 8/10
#
# Epoch 47/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.18s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.70s/it]
# Train Loss: 0.0273 | Val Loss: 0.0434 | IoU: 0.3095 | F1: 0.3850 | Precision: 0.4343 | Recall: 0.3848
# No improvement. EarlyStopping counter: 9/10
#
# Epoch 48/50
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [01:32<00:00,  3.17s/it]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.71s/it]
# Train Loss: 0.0281 | Val Loss: 0.0350 | IoU: 0.3261 | F1: 0.3780 | Precision: 0.4190 | Recall: 0.3773
# No improvement. EarlyStopping counter: 10/10
# ⏹️ Early stopping triggered.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_f1</td><td>▁▁▁▁▁▁▂▁▁▂▂▂▂▂▂▃▃▅▆▄▆▆▅▅▆▇▆▅▇▇▇▇▇▇▆▇▆▇▇█</td></tr><tr><td>val_iou</td><td>▁▂▂▁▁▁▁▁▂▁▂▂▂▂▂▃▃▅▅▄▅▅▄▄▅▆▇▅▇▆▇▆█▇▆▇▇▇██</td></tr><tr><td>val_loss</td><td>█▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_precision</td><td>▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▃▄▅▆▄▆▆▅▅▆▆▆▅▇▆▇▇▇▇▅▆▇▇██</td></tr><tr><td>val_recall</td><td>▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▃▄▆▆▅▆▆▆▆▆▇▆▆▇▇▇▇██▇█▇▇██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>0.02726</td></tr><tr><td>val_f1</td><td>0.385</td></tr><tr><td>val_iou</td><td>0.30953</td></tr><tr><td>val_loss</td><td>0.04343</td></tr><tr><td>val_precision</td><td>0.43429</td></tr><tr><td>val_recall</td><td>0.38478</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">run_WE3DS_seg_MNV2+UNet_bs64</strong> at: <a href='https://wandb.ai/federico-dittaro-university-of-udine/Second_phase_WE3DS_dataset-segmentation/runs/q9bhkbf2' target="_blank">https://wandb.ai/federico-dittaro-university-of-udine/Second_phase_WE3DS_dataset-segmentation/runs/q9bhkbf2</a><br> View project at: <a href='https://wandb.ai/federico-dittaro-university-of-udine/Second_phase_WE3DS_dataset-segmentation' target="_blank">https://wandb.ai/federico-dittaro-university-of-udine/Second_phase_WE3DS_dataset-segmentation</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250714_140435-q9bhkbf2/logs</code>

# %%
"""Carica i nomi delle classi e i rispettivi colori RGB"""
def load_class_info(colors_path, names_path):
    with open(colors_path, 'r') as f:
        class_colors = [list(map(int, line.strip().split(','))) for line in f]
    with open(names_path, 'r') as f:
        class_names = [line.strip() for line in f]
    return np.array(class_colors), class_names

class_colors, class_names = load_class_info(
    "../../../WE3DS-dataset/class_colors.txt",
    "../../../WE3DS-dataset/class_names.txt"
)

# %%
"""Carica il modello addestrato e lo imposta in modalità di valutazione"""
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.load_state_dict(torch.load("MNV2+UNet_models/MBV2UNet_WE3DS_segmentation_bs64.pth", map_location=device))
model.to(device)
model.eval()

val_transform = A.Compose([A.Resize(256, 256)])

test_dataset = WE3DSDataset(
    image_ids=test_ids,
    images_dir="../../../WE3DS-dataset/images",
    masks_dir="../../../WE3DS-dataset/annotations/segmentation/SegmentationLabel",
    transform=val_transform
)
# Out:
# /tmp/ipykernel_1935/2090933747.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("MNV2+UNet_models/MBV2UNet_WE3DS_segmentation_bs64.pth", map_location=device))

# %%
"""Trasforma una maschera di segmentazione in un'immagine colorata RGB
creando un'immagine vuota per poi colorare i pixel della maschera con il colore corrispondente"""
def decode_segmap(mask, class_colors):
    h, w = mask.shape
    color_mask = np.zeros((h, w, 3), dtype=np.uint8)
    for class_idx, color in enumerate(class_colors):
        color_mask[mask == class_idx] = color
    return color_mask

# %%
def print_test_images(test_ids):
    print("Immagini nel test set:")
    for img_id in test_ids:
        print(f"img_{img_id}.png")

print_test_images(test_ids)
# Out:
# Immagini nel test set:
# img_02415.png
# img_02330.png
# img_01036.png
# img_01064.png
# img_01819.png
# img_00483.png
# img_02166.png
# img_01111.png
# img_01304.png
# img_01530.png
# img_00842.png
# img_01307.png
# img_00281.png
# img_01207.png
# img_02183.png
# img_00160.png
# img_02145.png
# img_01268.png
# img_01834.png
# img_00087.png
# img_00935.png
# img_01771.png
# img_01003.png
# img_01517.png
# img_02098.png
# img_01106.png
# img_01239.png
# img_02320.png
# img_00871.png
# img_01882.png
# img_01755.png
# img_00253.png
# img_00683.png
# img_02115.png
# img_01026.png
# img_02102.png
# img_01282.png
# img_02442.png
# img_02333.png
# img_01599.png
# img_00387.png
# img_00463.png
# img_00431.png
# img_00880.png
# img_00157.png
# img_00393.png
# img_02311.png
# img_00317.png
# img_00038.png
# img_00037.png
# img_00121.png
# img_02028.png
# img_02173.png
# img_01356.png
# img_02338.png
# img_01899.png
# img_01505.png
# img_00605.png
# img_02061.png
# img_00123.png
# img_00911.png
# img_00101.png
# img_00044.png
# img_01782.png
# img_02535.png
# img_00876.png
# img_02294.png
# img_01462.png
# img_02516.png
# img_02095.png
# img_00305.png
# img_00411.png
# img_01887.png
# img_01073.png
# img_02382.png
# img_00713.png
# img_02279.png
# img_02212.png
# img_00782.png
# img_00817.png
# img_01950.png
# img_01706.png
# img_01058.png
# img_00190.png
# img_02087.png
# img_00107.png
# img_00879.png
# img_02254.png
# img_00169.png
# img_02256.png
# img_01325.png
# img_01600.png
# img_02144.png
# img_01132.png
# img_01649.png
# img_01828.png
# img_01159.png
# img_00861.png
# img_01441.png
# img_00049.png
# img_01323.png
# img_01292.png
# img_00890.png
# img_02091.png
# img_00023.png
# img_01196.png
# img_00510.png
# img_02405.png
# img_01844.png
# img_00356.png
# img_01958.png
# img_00176.png
# img_00931.png
# img_00912.png
# img_01040.png
# img_00254.png
# img_00635.png
# img_02487.png
# img_01386.png
# img_00338.png
# img_01476.png
# img_01017.png
# img_00040.png
# img_01139.png
# img_00085.png
# img_00981.png
# img_00858.png
# img_02140.png
# img_01878.png
# img_01623.png
# img_00419.png
# img_01474.png
# img_01731.png
# img_01914.png
# img_00365.png
# img_00708.png
# img_00501.png
# img_00503.png
# img_02172.png
# img_01170.png
# img_01580.png
# img_01222.png
# img_00830.png
# img_01544.png
# img_01200.png
# img_01841.png
# img_02310.png
# img_01972.png
# img_00221.png
# img_01928.png
# img_01955.png
# img_00607.png
# img_02135.png
# img_02468.png
# img_00545.png
# img_01363.png
# img_00262.png
# img_00630.png
# img_00915.png
# img_00322.png
# img_00113.png
# img_02385.png
# img_00324.png
# img_01709.png
# img_00482.png
# img_02048.png
# img_01160.png
# img_02126.png
# img_00385.png
# img_00725.png
# img_01412.png
# img_01936.png
# img_01190.png
# img_02265.png
# img_00384.png
# img_00715.png
# img_00404.png
# img_02199.png
# img_01423.png
# img_02495.png
# img_01639.png
# img_00958.png
# img_01889.png
# img_01956.png
# img_01062.png
# img_00186.png
# img_00164.png
# img_00650.png
# img_00367.png
# img_00891.png
# img_01100.png
# img_01094.png
# img_02195.png
# img_02300.png
# img_02181.png
# img_01758.png
# img_02490.png
# img_01980.png
# img_02042.png
# img_02216.png
# img_02524.png
# img_00789.png
# img_00080.png
# img_02401.png
# img_02285.png
# img_02488.png
# img_00258.png
# img_00167.png
# img_00358.png
# img_00116.png
# img_00800.png
# img_01254.png
# img_02286.png
# img_00039.png
# img_01778.png
# img_02428.png
# img_01877.png
# img_01344.png
# img_00361.png
# img_02293.png
# img_01813.png
# img_01946.png
# img_01714.png
# img_01478.png
# img_00418.png
# img_00906.png
# img_00637.png
# img_01387.png
# img_01514.png
# img_01851.png
# img_01590.png
# img_01825.png
# img_02148.png
# img_02555.png
# img_01177.png
# img_01781.png
# img_00740.png
# img_01564.png
# img_00947.png
# img_01038.png
# img_01184.png
# img_01496.png
# img_01067.png
# img_00621.png
# img_00216.png
# img_01163.png
# img_01140.png
# img_00453.png
# img_00942.png
# img_00165.png
# img_00184.png
# img_02530.png
# img_02325.png
# img_00860.png
# img_00189.png
# img_01410.png
# img_01119.png
# img_00464.png
# img_00834.png
# img_01346.png
# img_02561.png
# img_00335.png
# img_01101.png
# img_01059.png
# img_00578.png
# img_01926.png
# img_00096.png
# img_01678.png
# img_00811.png
# img_00489.png
# img_02164.png
# img_01025.png
# img_02469.png
# img_00572.png
# img_01909.png
# img_02331.png
# img_01760.png
# img_00272.png
# img_01013.png
# img_00844.png
# img_01707.png
# img_01335.png
# img_01759.png
# img_02421.png
# img_02406.png
# img_01799.png
# img_01978.png
# img_02169.png
# img_01444.png
# img_02559.png
# img_01230.png
# img_00776.png
# img_00814.png
# img_01178.png
# img_00041.png
# img_00877.png
# img_02479.png
# img_01406.png
# img_00780.png
# img_00558.png
# img_01452.png
# img_01700.png
# img_00978.png
# img_01083.png
# img_01503.png
# img_01272.png
# img_00301.png
# img_01422.png
# img_02388.png
# img_01329.png
# img_02398.png
# img_02215.png
# img_02287.png
# img_02485.png
# img_01076.png
# img_00436.png
# img_00579.png
# img_02459.png
# img_01575.png
# img_02422.png
# img_02248.png
# img_01483.png
# img_02386.png
# img_00562.png
# img_02214.png
# img_01593.png
# img_02031.png
# img_02083.png
# img_01583.png
# img_00162.png
# img_01645.png
# img_00030.png
# img_01041.png
# img_01843.png
# img_01913.png
# img_01109.png
# img_01409.png
# img_00509.png
# img_00549.png
# img_00862.png
# img_00487.png
# img_01326.png
# img_01090.png
# img_01839.png
# img_02088.png
# img_01341.png
# img_00982.png
# img_01934.png
# img_01697.png
# img_02302.png
# img_01964.png
# img_02438.png
# img_01310.png
# img_00307.png
# img_00002.png
# img_01660.png
# img_01497.png
# img_01659.png
# img_02039.png
# img_00576.png
# img_01257.png
# img_02084.png
# img_00152.png
# img_01169.png
# img_00837.png
# img_00945.png
# img_02074.png
# img_00479.png
# img_01751.png
# img_00172.png
# img_00381.png
# img_02163.png
# img_00610.png
# img_00930.png
# img_01657.png
# img_00536.png
# img_00709.png
# img_01628.png
# img_00681.png
# img_00069.png
# img_00084.png
# img_00685.png
# img_01763.png
# img_02029.png
# img_02383.png
# img_00440.png

# %%
def visualize_prediction(filename, model, dataset):
    img_id = filename.replace("img_", "").replace(".png", "")
    idx = dataset.image_ids.index(img_id)
    image, mask = dataset[idx]
    input_tensor = image.unsqueeze(0).to(device)

    with torch.no_grad():
        output = model(input_tensor)
        pred = torch.argmax(output.squeeze(), dim=0).cpu().numpy()

    image_np = image.permute(1, 2, 0).numpy()
    mask_np = mask.numpy()

    mask_rgb = decode_segmap(mask_np, class_colors)
    pred_rgb = decode_segmap(pred, class_colors)

    plt.figure(figsize=(15, 5))

    plt.subplot(1, 3, 1)
    plt.imshow(image_np)
    plt.title("Immagine")
    plt.axis("off")

    plt.subplot(1, 3, 2)
    plt.imshow(mask_rgb)
    plt.title("Maschera Reale")
    plt.axis("off")

    plt.subplot(1, 3, 3)
    plt.imshow(pred_rgb)
    plt.title("Predizione")
    plt.axis("off")

    plt.tight_layout()
    plt.show()
visualize_prediction("img_01503.png", model, test_dataset)

# img_00858.png    img_00740.png     img_01178.png    img_01503.png
